# %%
import os

from tools.serp import search_img

# %%
search_img('https://i.imgur.com/HBrB8p0.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 search_img('https://i.imgur.com/HBrB8p0.png')
#
# File ~/dev/llm/geolocation/tools/serp.py:22, in search_img(img_path)
#      14 def search_img(img_path:str):
#      15     """
#      16     Searches Google Lens for an image
#      17     :param img_path:
#      18     :return:
#      19     """
#      20     params = {
#      21         'api_key': SERP_API_KEY,
# ---> 22         'engine': "google_lens",
#      23         'url': urllib.parse.quote(encode_image(Path(img_path)), safe='/', encoding=None, errors=None)
#      24     }
#      25     search = GoogleSearch(params)
#      26     results = search.get_dict()
#
# File ~/dev/llm/geolocation/utils.py:53, in encode_image(image, max_size_mb)
#      50 def encode_image(image: Image.Image | Path, max_size_mb=20):
# ...

# %%
from serpapi import GoogleSearch
import dotenv
import os
dotenv.load_dotenv()
params = {
        'api_key': os.getenv('SERP_API_KEY'),
        'engine': "google_lens",
        'url': 'https://i.imgur.com/HBrB8p0.png'
    }
search = GoogleSearch(params)
search

# %%
search.get_dict()
# Out:
# {'search_metadata': {'id': '65ab94c67f8361da5010a23f',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/f06df42a6b78a6e0/65ab94c67f8361da5010a23f.json',
#   'created_at': '2024-01-20 09:39:18 UTC',
#   'processed_at': '2024-01-20 09:39:18 UTC',
#   'google_lens_url': 'https://lens.google.com/uploadbyurl?url=https://i.imgur.com/HBrB8p0.png',
#   'raw_html_file': 'https://serpapi.com/searches/f06df42a6b78a6e0/65ab94c67f8361da5010a23f.html',
#   'prettify_html_file': 'https://serpapi.com/searches/f06df42a6b78a6e0/65ab94c67f8361da5010a23f.prettify',
#   'total_time_taken': 1.4},
#  'search_parameters': {'engine': 'google_lens',
#   'url': 'https://i.imgur.com/HBrB8p0.png'},
#  'visual_matches': [{'position': 1,
#    'title': 'Danny DeVito - Simple English Wikipedia, the free encyclopedia',
#    'link': 'https://simple.wikipedia.org/wiki/Danny_DeVito',
#    'source': 'Wikipedia',
# ...

# %%
search.get_dict()['visual_matches']
# Out:
# [{'position': 1,
#   'title': 'Danny DeVito - Simple English Wikipedia, the free encyclopedia',
#   'link': 'https://simple.wikipedia.org/wiki/Danny_DeVito',
#   'source': 'Wikipedia',
#   'source_icon': 'https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcRUUbshUnin7ULaNODrg-lVcNBBMXFVfEUVbn_C-R6DJs51ANOoaJ90cg3hAt9FlHNrsWSlR0ODkNyjM15te9yLoYt4MoTFuNUPBNA33tYYl8mAb1r6uwwt4A',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSm5zQhimRYYgKPVf16viNFoDSsZmGrH09dthR6cpL1DXEdzmQu'},
#  {'position': 3,
#   'title': 'File:Danny DeVito (4842605007).jpg - Wikipedia',
#   'link': 'https://en.wikipedia.org/wiki/File:Danny_DeVito_(4842605007).jpg',
#   'source': 'Wikipedia',
#   'source_icon': 'https://encrypted-tbn2.gstatic.com/favicon-tbn?q=tbn:ANd9GcRLIcgPlYxOaoBg0MnSobLYyflrgF_RLdwAY09AXHWGy2jqWQnuIBNCY5I1BuzY7jeAJga0y0b9htBHe94i3Pg4B0NhHMNDVsmS-FVRKL014d-Xf6sX',
# ...

# %%
import requests
r = requests.get("https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTIT5mxxg7v8mxodEyuG6p3cr1LEri-OvEx-0q4-9dQcor8Hywo")
r
# Out:
# <Response [200]>

# %%
# r is an image, display it:
from IPython.display import Image
Image(r.content)
